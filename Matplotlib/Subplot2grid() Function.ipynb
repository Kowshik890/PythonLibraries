# %% [markdown]
# Subplot2grid() Function is used to span across multiple rows or columns.
# plt.subplot2grid(shape, location, rowspan, colspan)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 10)

a1 = plt.subplot2grid((3, 3), (0, 0), colspan = 2)
a1.plot(x, np.exp(x))
a1.set_title('Exp')

a2 = plt.subplot2grid((3, 3), (1, 0), colspan = 2, rowspan = 2)
a2.plot(x, np.log(x))
a2.set_title('Log')

a3 = plt.subplot2grid((3, 3), (0, 2), rowspan = 3)
a3.plot(x, np.square(x))   # Alternate way --> a3.plot(x, np.power(x, 2))
a3.set_title('Square')

plt.tight_layout()     # This function is used to maintain a proper distance from one plot to another.
plt.show()
